# %% [markdown]
# <a href="https://colab.research.google.com/github/ai7dnn/2021-2-DNN/blob/main/code/21_1_myfirst_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'

# %%
import sklearn as sk
sk.__version__
# Out:
# '0.22.2.post1'

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.7/dist-packages']

# %%
a, b = 10, 20

# %%
a + b
# Out:
# 30

# %%
x = tf.constant(10)
x
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=10>

# %%
x
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=10>

# %%
x.numpy()
# Out:
# 10

# %%
y = tf.constant(20)
y
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=20>

# %%
y.numpy()
# Out:
# 20

# %%
x + y
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=30>

# %%
z = x + y
z
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=30>

# %%
z.numpy()
# Out:
# 30

# %%
m = tf.constant([1, 2, 3])
m
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([1, 2, 3], dtype=int32)>

# %%
m.numpy()
# Out:
# array([1, 2, 3], dtype=int32)

# %%
tf.executing_eagerly()
# Out:
# True

# %%
# 텐서플로 1.0 버전 선택
try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
except Exception:
    pass

import tensorflow as tf
tf.__version__
# Out:
# '2.5.0'

# %%
tf.executing_eagerly()
# Out:
# True

# %%
import tensorflow as tf

hello = tf.constant('Hello World!')
print(hello)
print(hello.numpy())
# Out:
# tf.Tensor(b'Hello World!', shape=(), dtype=string)
# b'Hello World!'

# %%
a = tf.constant(5)
b = tf.constant(3)
print(a+b)
(a+b).numpy()
# Out:
# tf.Tensor(8, shape=(), dtype=int32)
# 8
