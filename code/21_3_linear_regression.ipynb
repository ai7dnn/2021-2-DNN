# %% [markdown]
# <a href="https://colab.research.google.com/github/ai7dnn/2021-2-DNN/blob/main/code/21_3_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 일차함수 관계식 찾기

# %% [markdown]
# x 변수, y 변수 데이터 만들기 (리스트 객체)

# %%
x = [-3,  31,  -11,  4,  0,  22, -2, -5, -25, -14]
y = [ -2,   32,   -10,   5,  1,   23,  -1,  -4, -24,  -13]
print(x)
print(y)
# Out:
# [-3, 31, -11, 4, 0, 22, -2, -5, -25, -14]
# [-2, 32, -10, 5, 1, 23, -1, -4, -24, -13]

# %% [markdown]
# 그래프 그리기 (matplotlib)

# %%
import matplotlib.pyplot as plt
plt.plot(x, y)
plt.show()

# %% [markdown]
# - 판다스 데이터프레임 만들기

# %%
x
# Out:
# [-3, 31, -11, 4, 0, 22, -2, -5, -25, -14]

# %%
y
# Out:
# [-2, 32, -10, 5, 1, 23, -1, -4, -24, -13]

# %%
import pandas as pd
df = pd.DataFrame({'X':x, 'Y':y})
df.shape
# Out:
# (10, 2)

# %%
df
# Out:
#     X   Y
# 0  -3  -2
# 1  31  32
# 2 -11 -10
# 3   4   5
# 4   0   1
# 5  22  23
# 6  -2  -1
# 7  -5  -4
# 8 -25 -24
# 9 -14 -13

# %%
df.head(3)
# Out:
#     X   Y
# 0  -3  -2
# 1  31  32
# 2 -11 -10

# %%
df.tail()
# Out:
#     X   Y
# 5  22  23
# 6  -2  -1
# 7  -5  -4
# 8 -25 -24
# 9 -14 -13

# %% [markdown]
# 머신러닝 - 사이킷런 *LinearRegression* 모형

# %%
df
# Out:
#     X   Y
# 0  -3  -2
# 1  31  32
# 2 -11 -10
# 3   4   5
# 4   0   1
# 5  22  23
# 6  -2  -1
# 7  -5  -4
# 8 -25 -24
# 9 -14 -13

# %%
train_features = ['X']
target_cols = ['Y']
X_train = df.loc[:, train_features]
y_train = df.loc[:, target_cols]
print(X_train.shape, y_train.shape)
# Out:
# (10, 1) (10, 1)

# %%
X_train
# Out:
#     X
# 0  -3
# 1  31
# 2 -11
# 3   4
# 4   0
# 5  22
# 6  -2
# 7  -5
# 8 -25
# 9 -14

# %%
y_train
# Out:
#     Y
# 0  -2
# 1  32
# 2 -10
# 3   5
# 4   1
# 5  23
# 6  -1
# 7  -4
# 8 -24
# 9 -13

# %%
df
# Out:
#     X   Y
# 0  -3  -2
# 1  31  32
# 2 -11 -10
# 3   4   5
# 4   0   1
# 5  22  23
# 6  -2  -1
# 7  -5  -4
# 8 -25 -24
# 9 -14 -13

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.coef_, lr.intercept_
# Out:
# (array([[1.]]), array([1.]))

# %%
print ("기울기: ", lr.coef_[0][0])
print ("y절편: ", lr.intercept_[0])
# Out:
# 기울기:  0.9999999999999999
# y절편:  0.9999999999999999

# %%
import numpy as np
X_new = np.array(20).reshape(1, 1)
X_new
# Out:
# array([[20]])

# %%
lr.predict(X_new)
# Out:
# array([[21.]])

# %%
X_test = np.arange(11, 16, 1).reshape(-1, 1)
X_test
# Out:
# array([[11],
#        [12],
#        [13],
#        [14],
#        [15]])

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([[12.],
#        [13.],
#        [14.],
#        [15.],
#        [16.]])
